# %%
## Normal Setup stuff
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import linecache
font = {'family' : 'sans-serif', 'weight' : 'normal', 'size'   : 16}
matplotlib.rc('font', **font)
# from __future__ import division ## Python 3.0 returns the quotient in decimal form

# %%
file_name = "DataLogTest.txt"


fo = open(file_name,'r')

# print(file.readline())
# print(fo.read())
target_line = open(file_name).readlines()
print("Target line is",target_line)




num_lines = len(open(file_name).readlines())
print("Total number of lines in file",num_lines)

for x in range(1,(num_lines+1)):
    print("Current Target: ", linecache.getline(file_name,x))



# def Find_Qunatity(target_line,f_name):
#     n_lines = (len(open(f_name).readlines()) + 1)
#     for x in range(0,n_lines):
#         current_line = linecache.getline(f_name,x)
# #         print("Current Line:",current_line)
#         if target_line in current_line:
#             return current_line
            
        
# found_value = Find_Qunatity("Mode",file_name)

# print(found_value)
# print(found_value.split(' '))
# Out:
# Target line is ['1593092040.400000 System: \n', '\n', 'SN: M0001138   Motor Ver: 5.1.10 - SYS_FILERESET\n', '1593092040.900000 System: Bluetooth Connection: Disconnected\n', '1593092055.510000  Elbow: Flx Cycle Count: 0\n', '1593092055.530000  Elbow: Ext Cycle Count: 0\n', '1593092055.560000  Elbow: Flx Motor Time: 0 mSecs\n', '1593092055.580000  Elbow: Ext Motor Time: 0 mSecs\n', '1593092055.600000  Elbow: Motor Current Position: 0\n', '1593092055.620000  Elbow: Motor Maximum Position: 135\n', '1593092055.640000  Elbow: Biceps Mode Parameters  (G,B,T): 4/4, 4/4, 11/11\n', '1593092055.660000  Elbow: Elbow Orientation: Right\n', '1593092055.680000  Elbow: Flex Limit: 135 deg\n', '1593092055.700000  Elbow: Extend Limit: 0 deg\n', '1593092055.720000  Elbow: Motor Temperature: 78 F\n', '1593092055.740000  Elbow: Mode: 1 (Flex)\n', '1593092055.760000 System: Battery Capacity: 83.00 %\n', '1593092055.790000 System: Current: -0.13 Amps\n', '1593092055.810000 System: Battery Cycle Count: 3\n
# ...
