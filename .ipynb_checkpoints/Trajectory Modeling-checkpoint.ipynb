# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
from scipy import signal
# Polynomial = np.polynomial.Polynomial
# %matplotlib inline
import math
import scipy.stats as stats


font = {'family' : 'sans-serif', 'weight' : 'normal', 'size'   : 16}
matplotlib.rc('font', **font)

# %%
mu = 0
variance = 1
t = np.arange(0, 3.14, 0.1) #Domain of EMG values 
x = [-1,0,1,2,3,4,5]
y = [ 0,5,5,5,5,5,5]

amplitude   = 2*np.sin(t)
sigma = math.sqrt(variance)
# x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.plot(t, amplitude)
plt.legend(['Desired Position','Desired Velocity'])
plt.xlabel('Time [s]')
plt.ylabel('Joint Position [% ROM]')
# Out:
# Text(0, 0.5, 'Joint Position [% ROM]')

# %%
t = np.linspace(0, 1, 100) #Domain of EMG values 

q0 = 0
qf = 1
q_d = (qf-q0)

q = q0 + 3*q_d*(np.power(t,2)) - 2*q_d*(np.power(t,3))
v = 6*q_d*t - 6*q_d*(np.power(t,2))


plt.figure(figsize=(10,10))
plt.plot(t,q)
plt.xlabel('Time [s]')
plt.ylabel('Joint Position [Deg]')
plt.title('Position Trajectory')

plt.figure(figsize=(10,10))
plt.plot(t,v)
plt.xlabel('Time [s]')
plt.ylabel('Joint Velocity [Deg/sec]')
plt.title('Velocity Trajectory')
# Out:
# Text(0.5, 1.0, 'Velocity Trajectory')

# %%
t0 = 0
tf = 1

t = np.linspace(t0, tf, 100) #Domain of EMG values 

step = 5

q0 = 30
qf = q0 + step

q0_dot = 0
qf_dot = 0

a0 = q0
a1 = q0_dot

a2 = ((3/(np.power(tf,2))*(qf-q0)))    - ((2/tf)*q0_dot) - ((1/tf)*qf_dot)
a3 = (-2/(np.power(tf,3))) * (qf-q0) +(1/(np.power(tf,2)))*(qf_dot - q0_dot)


q = a0 + (a1*t) + (a2*(np.power(t,2))) + (a3*(np.power(t,3)))
v = a1 + (2*a2*t) + (3*a3*(np.power(t,3)))
        
plt.figure(figsize=(10,10))
plt.plot(t,q)
plt.xlabel('Time [s]')
plt.ylabel('Joint Position [Deg]')
plt.title('Position Trajectory')

plt.figure(figsize=(10,10))
plt.plot(t,v)
plt.xlabel('Time [s]')
plt.ylabel('Joint Velocity [Deg/sec]')
plt.title('Velocity Trajectory')

print(q)
# Out:
# [0.00000000e+00 3.04029995e-03 1.20787510e-02 2.69916799e-02
#  4.76554134e-02 7.39462784e-02 1.05740602e-01 1.42914710e-01
#  1.85344930e-01 2.32907588e-01 2.85479012e-01 3.42935528e-01
#  4.05153463e-01 4.72009144e-01 5.43378897e-01 6.19139049e-01
#  6.99165927e-01 7.83335858e-01 8.71525169e-01 9.63610186e-01
#  1.05946724e+00 1.15897265e+00 1.26200274e+00 1.36843385e+00
#  1.47814230e+00 1.59100442e+00 1.70689653e+00 1.82569497e+00
#  1.94727605e+00 2.07151610e+00 2.19829145e+00 2.32747844e+00
#  2.45895337e+00 2.59259259e+00 2.72827242e+00 2.86586918e+00
#  3.00525920e+00 3.14631882e+00 3.28892434e+00 3.43295211e+00
#  3.57827845e+00 3.72477968e+00 3.87233214e+00 4.02081214e+00
#  4.17009602e+00 4.32006011e+00 4.47058072e+00 4.62153419e+00
#  4.77279684e+00 4.92424500e+00 5.07575500e+00 5.22720316e+00
#  5.37846581e+00 5.52941928e+00 5.67993989e+00 5.82990398e+00
#  5.97918786e+00 6.12766786e+00 6.27522032e+00 6.42172155e+00
#  6.56704789e+00 6.71107566e+00 6.85368118e+00 6.99474080e+00
#  7.13413082e+00 7.27172758e+00 7.40740741e+00 7.54104663e+00
#  7.67252156e+00 7.80170855e+00 7.92848390e+00 8.05272395e+00
#  8.17430503e+00 8.29310347e+00 8.40899558e+00 8.52185770e+00
#  8.63156615e+00 8.73799726e+00 8.84102735e+00 8.94053276e+00
#  9.03638981e+00 9.12847483e+00 9.21666414e+00 9.30083407e+00
#  9.38086095e+00 9.45662110e+00 9.52799086e+00 9.59484654e+00
#  9.65706447e+00 9.71452099e+00 9.76709241e+00 9.81465507e+00
#  9.85708529e+00 9.89425940e+00 9.92605372e+00 9.95234459e+00
#  9.97300832e+00 9.98792125e+00 9.99695970e+00 1.00000000e+01]

# %%
q = q0 + (9.379 * t) - (6.25 * (np.power(t,3))) + ((1.879)*(np.power(t,5)))
v = 9.379 - (18.75 * (np.power(t,2))) + (9.395 * (np.power(t,4)))
a = (-37.5 * t) + (37.5 * (np.power(t,3)))



plt.figure(figsize=(10,10))
plt.plot(t,q)
plt.xlabel('Time [s]')
plt.ylabel('Joint Position [Deg]')
plt.title('Position Trajectory')

plt.figure(figsize=(10,10))
plt.plot(t,v)
plt.xlabel('Time [s]')
plt.ylabel('Joint Velocity [Deg/sec]')
plt.title('Velocity Trajectory')


plt.figure(figsize=(10,10))
plt.plot(t,a)
plt.xlabel('Time [s]')
plt.ylabel('Joint Accleration [Deg/sec2]')
plt.title('Accel Trajectory')
# Out:
# Text(0.5, 1.0, 'Accel Trajectory')
